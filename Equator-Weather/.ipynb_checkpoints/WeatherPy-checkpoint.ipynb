# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import scipy.stats as st
from scipy.stats import linregress

from config import weather_api_key

from citipy import citipy

output_data = "../data/cities.csv"

lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
lat_lngs = []
cities = []
country_code = []

lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    country = citipy.nearest_city(lat_lng[0], lat_lng[1]).country_code
    if city not in cities:
        cities.append(city)
        country_code.append(country)
        
        
print(len(cities))
print(cities[0:30])
# Out:
# 626
# ['chuy', 'new norfolk', 'hithadhoo', 'lasa', 'dillon', 'saldanha', 'albany', 'punta arenas', 'mataura', 'port augusta', 'port-gentil', 'santa maria', 'atuona', 'upernavik', 'kapaa', 'poum', 'tanete', 'houma', 'georgetown', 'wuhu', 'barrow', 'cherskiy', 'rikitea', 'saint-philippe', 'hualmay', 'cabo san lucas', 'kutum', 'cidreira', 'naron', 'hami']

# %%
print(len(cities))
print(cities[0:30],country_code[0:30])
# Out:
# 626
# ['chuy', 'new norfolk', 'hithadhoo', 'lasa', 'dillon', 'saldanha', 'albany', 'punta arenas', 'mataura', 'port augusta', 'port-gentil', 'santa maria', 'atuona', 'upernavik', 'kapaa', 'poum', 'tanete', 'houma', 'georgetown', 'wuhu', 'barrow', 'cherskiy', 'rikitea', 'saint-philippe', 'hualmay', 'cabo san lucas', 'kutum', 'cidreira', 'naron', 'hami'] ['uy', 'au', 'mv', 'cn', 'us', 'za', 'au', 'cl', 'pf', 'au', 'ga', 'cv', 'pf', 'gl', 'us', 'nc', 'id', 'us', 'sh', 'cn', 'us', 'ru', 'pf', 're', 'pe', 'mx', 'sd', 'br', 'es', 'cn']

# %%
units = "imperial"
url = "http://api.openweathermap.org/data/2.5/weather?"

query_url = f"{url}appid={weather_api_key}&units={units}&q="
city_lat = []
city_lng = []
weather = []
humidity = []
cloudiness = []
wind_speed = []
city_list = []
country_list = []




for x in range(len(cities)):
    city = cities[x]
    response = requests.get(f"{query_url}{city},{country_code[x]}").json()
    
    if city not in city_list:
        
        try:
            city_lat.append(response["coord"]["lat"])
            city_lng.append(response["coord"]["lon"])
            weather.append(response["main"]["temp"])
            humidity.append(response["main"]["humidity"])
            cloudiness.append(response["clouds"]["all"])
            wind_speed.append(response["wind"]["speed"])
            city_list.append(cities[x])
            country_list.append(country_code[x])
        
            print(f"Retrieving info for {x+1} of {len(cities)} cities. | {city}")
    
        except KeyError:
            print(f"No matching city found.  Skipped. | {city}")
    else:
        print(f"Redundant city found. Skipped. | {city}")

    time.sleep(1)
# Out:
# Retrieving info for 1 of 626 cities. | chuy
# Retrieving info for 2 of 626 cities. | new norfolk
# Retrieving info for 3 of 626 cities. | hithadhoo
# No matching city found.  Skipped. | lasa
# Retrieving info for 5 of 626 cities. | dillon
# Retrieving info for 6 of 626 cities. | saldanha
# Retrieving info for 7 of 626 cities. | albany
# Retrieving info for 8 of 626 cities. | punta arenas
# No matching city found.  Skipped. | mataura
# Retrieving info for 10 of 626 cities. | port augusta
# Retrieving info for 11 of 626 cities. | port-gentil
# Retrieving info for 12 of 626 cities. | santa maria
# Retrieving info for 13 of 626 cities. | atuona
# Retrieving info for 14 of 626 cities. | upernavik
# Retrieving info for 15 of 626 cities. | kapaa
# Retrieving info for 16 of 626 cities. | poum
# Retrieving info for 17 of 626 cities. | tanete
# Retrieving info for 18 of 626 cities. | houma
# Retrieving info for 19 of 626 cities. | georgetown
# Retrieving info for 20 of 626 cities. | wuhu
# Retrieving info for 21 of 626 cities. | barrow
# Retrieving info for 22 of 626 cities. | cherskiy
# Retrieving info for 23 of 626 cities. | rikitea
# Retrieving info for 24 of 626 cities. | saint-philippe
# Retrieving info for 25 of 626 cities. | hualmay
# Retrieving info for 26 of 626 cities. | cabo san lucas
# Retrieving info for 27 of 626 cities. | kutum
# Retrieving info for 28 of 626 cities. | cidreira
# Retrieving info for 29 of 626 cities. | naron
# Retrieving info for 30 of 626 cities. | hami
# Retrieving info for 31 of 626 cities. | victoria
# Retrieving info for 32 of 626 cities. | lazaro cardenas
# Retrieving info for 33 of 626 cities. | sao filipe
# Retrieving info for 34 of 626 cities. | port alfred
# Retrieving info for 35 of 626 cities. | bluff
# Retrieving info for 36 of 626 cities. | merauke
# Retrieving info for 37 of 626 cities. | east london
# Retrieving info for 38 of 626 cities. | pevek
# Retrieving info for 39 of 626 cities. | cairns
# Retrieving info for 40 of 626 cities. | iqaluit
# Retrieving info for 41 of 626 cities. | arraial do cabo
# Retrieving info for 42 of 626 cities. | busselton
# No matching city found.  Skipped. | mys shmidta
# Retrieving info for 44 of 626 cities. | atikokan
# Retrieving info for 45 of 626 cities. | makakilo city
# Retrieving info for 46 of 626 cities. | vallenar
# Retrieving info for 47 of 626 cities. | nikolskoye
# Retrieving info for 48 of 626 cities. | butaritari
# Retrieving info for 49 of 626 cities. | ponta do sol
# Retrieving info for 50 of 626 cities. | iglesias
# Retrieving info for 51 of 626 cities. | vidim
# Retrieving info for 52 of 626 cities. | aksu
# Retrieving info for 53 of 626 cities. | villa carlos paz
# Retrieving info for 54 of 626 cities. | koutsouras
# Retrieving info for 55 of 626 cities. | kallidaikurichchi
# Retrieving info for 56 of 626 cities. | chengde
# No matching city found.  Skipped. | asau
# Retrieving info for 58 of 626 cities. | ushuaia
# Retrieving info for 59 of 626 cities. | san vito dei normanni
# Retrieving info for 60 of 626 cities. | dikson
# Retrieving info for 61 of 626 cities. | hamilton
# Retrieving info for 62 of 626 cities. | roros
# Retrieving info for 63 of 626 cities. | jamestown
# Retrieving info for 64 of 626 cities. | hermanus
# Retrieving info for 65 of 626 cities. | sendafa
# Retrieving info for 66 of 626 cities. | yellowknife
# Retrieving info for 67 of 626 cities. | teahupoo
# Retrieving info for 68 of 626 cities. | namatanai
# No matching city found.  Skipped. | bolungarvik
# Retrieving info for 70 of 626 cities. | new iberia
# Retrieving info for 71 of 626 cities. | keti bandar
# Retrieving info for 72 of 626 cities. | vardo
# Retrieving info for 73 of 626 cities. | mount isa
# Retrieving info for 74 of 626 cities. | puerto ayora
# Retrieving info for 75 of 626 cities. | shizunai
# Retrieving info for 76 of 626 cities. | havelock
# Retrieving info for 77 of 626 cities. | villaviciosa
# Retrieving info for 78 of 626 cities. | coquimbo
# Retrieving info for 79 of 626 cities. | necochea
# Retrieving info for 80 of 626 cities. | mandan
# Retrieving info for 81 of 626 cities. | mandalgovi
# No matching city found.  Skipped. | taolanaro
# No matching city found.  Skipped. | amderma
# Retrieving info for 84 of 626 cities. | khatanga
# Retrieving info for 85 of 626 cities. | geraldton
# Retrieving info for 86 of 626 cities. | te anau
# Retrieving info for 87 of 626 cities. | provideniya
# Retrieving info for 88 of 626 cities. | mehamn
# Retrieving info for 89 of 626 cities. | paamiut
# Retrieving info for 90 of 626 cities. | chiredzi
# No matching city found.  Skipped. | maimon
# Retrieving info for 92 of 626 cities. | adrar
# No matching city found.  Skipped. | candawaga
# Retrieving info for 94 of 626 cities. | ostrovnoy
# Retrieving info for 95 of 626 cities. | yulara
# Retrieving info for 96 of 626 cities. | korla
# Retrieving info for 97 of 626 cities. | chincha alta
# Retrieving info for 98 of 626 cities. | ribeira grande
# Retrieving info for 99 of 626 cities. | tazovskiy
# No matching city found.  Skipped. | barentsburg
# Retrieving info for 101 of 626 cities. | isla mujeres
# Retrieving info for 102 of 626 cities. | gordeyevka
# Retrieving info for 103 of 626 cities. | hilo
# Retrieving info for 104 of 626 cities. | kodiak
# Retrieving info for 105 of 626 cities. | saint george
# Retrieving info for 106 of 626 cities. | san andres
# Retrieving info for 107 of 626 cities. | san luis
# Retrieving info for 108 of 626 cities. | jardim
# Retrieving info for 109 of 626 cities. | qaanaaq
# Retrieving info for 110 of 626 cities. | thompson
# Retrieving info for 111 of 626 cities. | inirida
# No matching city found.  Skipped. | sentyabrskiy
# Retrieving info for 113 of 626 cities. | ulaanbaatar
# Retrieving info for 114 of 626 cities. | huarmey
# Retrieving info for 115 of 626 cities. | kampot
# Retrieving info for 116 of 626 cities. | vaini
# Retrieving info for 117 of 626 cities. | barabai
# Retrieving info for 118 of 626 cities. | rapid valley
# Retrieving info for 119 of 626 cities. | klaksvik
# Retrieving info for 120 of 626 cities. | lumphat
# Retrieving info for 121 of 626 cities. | letterkenny
# No matching city found.  Skipped. | qurayyat
# Retrieving info for 123 of 626 cities. | batemans bay
# Retrieving info for 124 of 626 cities. | lebu
# Retrieving info for 125 of 626 cities. | norman wells
# Retrieving info for 126 of 626 cities. | port lincoln
# Retrieving info for 127 of 626 cities. | naze
# Retrieving info for 128 of 626 cities. | saint-augustin
# Retrieving info for 129 of 626 cities. | camacha
# Retrieving info for 130 of 626 cities. | torbay
# Retrieving info for 131 of 626 cities. | cape town
# Retrieving info for 132 of 626 cities. | hailar
# Retrieving info for 133 of 626 cities. | svetlogorsk
# Retrieving info for 134 of 626 cities. | mandurah
# Retrieving info for 135 of 626 cities. | ahipara
# Retrieving info for 136 of 626 cities. | groton
# No matching city found.  Skipped. | illoqqortoormiut
# Retrieving info for 138 of 626 cities. | kaveripattinam
# Retrieving info for 139 of 626 cities. | aloleng
# Retrieving info for 140 of 626 cities. | clyde river
# Retrieving info for 141 of 626 cities. | tumaco
# Retrieving info for 142 of 626 cities. | banjar
# Retrieving info for 143 of 626 cities. | barcelona
# No matching city found.  Skipped. | attawapiskat
# Retrieving info for 145 of 626 cities. | oshikango
# Retrieving info for 146 of 626 cities. | fukue
# Retrieving info for 147 of 626 cities. | castro
# Retrieving info for 148 of 626 cities. | chake chake
# Retrieving info for 149 of 626 cities. | luderitz
# Retrieving info for 150 of 626 cities. | guerrero negro
# Retrieving info for 151 of 626 cities. | jiangyou
# Retrieving info for 152 of 626 cities. | port elizabeth
# Retrieving info for 153 of 626 cities. | benghazi
# Retrieving info for 154 of 626 cities. | touros
# Retrieving info for 155 of 626 cities. | banda aceh
# No matching city found.  Skipped. | blonduos
# Retrieving info for 157 of 626 cities. | hobart
# Retrieving info for 158 of 626 cities. | zhezkazgan
# No matching city found.  Skipped. | kuche
# Retrieving info for 160 of 626 cities. | avarua
# Retrieving info for 161 of 626 cities. | laguna
# Retrieving info for 162 of 626 cities. | tomatlan
# No matching city found.  Skipped. | meyungs
# No matching city found.  Skipped. | subaytilah
# Retrieving info for 165 of 626 cities. | caravelas
# Retrieving info for 166 of 626 cities. | russell
# Retrieving info for 167 of 626 cities. | serenje
# Retrieving info for 168 of 626 cities. | grand baie
# Retrieving info for 169 of 626 cities. | koster
# Retrieving info for 170 of 626 cities. | pisco
# Retrieving info for 171 of 626 cities. | alindao
# Retrieving info for 172 of 626 cities. | handan
# Retrieving info for 173 of 626 cities. | kahului
# Retrieving info for 174 of 626 cities. | garowe
# No matching city found.  Skipped. | abu samrah
# No matching city found.  Skipped. | nizhneyansk
# Retrieving info for 177 of 626 cities. | lompoc
# No matching city found.  Skipped. | chagda
# Retrieving info for 179 of 626 cities. | ayame
# Retrieving info for 180 of 626 cities. | saint-francois
# Retrieving info for 181 of 626 cities. | odessa
# Retrieving info for 182 of 626 cities. | esperance
# Retrieving info for 183 of 626 cities. | tuktoyaktuk
# Retrieving info for 184 of 626 cities. | havre-saint-pierre
# Retrieving info for 185 of 626 cities. | sambava
# Retrieving info for 186 of 626 cities. | tuatapere
# Retrieving info for 187 of 626 cities. | maracaibo
# No matching city found.  Skipped. | kadykchan
# Retrieving info for 189 of 626 cities. | yumen
# Retrieving info for 190 of 626 cities. | waipawa
# Retrieving info for 191 of 626 cities. | chimbote
# Retrieving info for 192 of 626 cities. | biabou
# Retrieving info for 193 of 626 cities. | anahuac
# No matching city found.  Skipped. | kamenskoye
# Retrieving info for 195 of 626 cities. | kaitangata
# Retrieving info for 196 of 626 cities. | hell
# Retrieving info for 197 of 626 cities. | shingu
# Retrieving info for 198 of 626 cities. | isla aguada
# Retrieving info for 199 of 626 cities. | kasongo
# Retrieving info for 200 of 626 cities. | praia
# No matching city found.  Skipped. | samalaeulu
# Retrieving info for 202 of 626 cities. | komsomolskiy
# Retrieving info for 203 of 626 cities. | salalah
# Retrieving info for 204 of 626 cities. | villa corzo
# Retrieving info for 205 of 626 cities. | hasaki
# Retrieving info for 206 of 626 cities. | ixtapa
# Retrieving info for 207 of 626 cities. | traralgon
# Retrieving info for 208 of 626 cities. | pampas
# No matching city found.  Skipped. | krasnousolskiy
# Retrieving info for 210 of 626 cities. | kathu
# Retrieving info for 211 of 626 cities. | paita
# Retrieving info for 212 of 626 cities. | padang
# Retrieving info for 213 of 626 cities. | bengkulu
# Retrieving info for 214 of 626 cities. | port hedland
# No matching city found.  Skipped. | nguiu
# Retrieving info for 216 of 626 cities. | faanui
# Retrieving info for 217 of 626 cities. | rumphi
# Retrieving info for 218 of 626 cities. | le pradet
# No matching city found.  Skipped. | marcona
# Retrieving info for 220 of 626 cities. | stromness
# Retrieving info for 221 of 626 cities. | palmer
# Retrieving info for 222 of 626 cities. | hambantota
# Retrieving info for 223 of 626 cities. | bredasdorp
# Retrieving info for 224 of 626 cities. | coihaique
# Retrieving info for 225 of 626 cities. | saint-pierre
# No matching city found.  Skipped. | mentok
# Retrieving info for 227 of 626 cities. | krasnoselkup
# Retrieving info for 228 of 626 cities. | namibe
# Retrieving info for 229 of 626 cities. | schwechat
# Retrieving info for 230 of 626 cities. | strezhevoy
# Retrieving info for 231 of 626 cities. | saskylakh
# Retrieving info for 232 of 626 cities. | aykhal
# Retrieving info for 233 of 626 cities. | kamennomostskoye
# Retrieving info for 234 of 626 cities. | hobyo
# Retrieving info for 235 of 626 cities. | mar del plata
# Retrieving info for 236 of 626 cities. | pangnirtung
# Retrieving info for 237 of 626 cities. | tete
# Retrieving info for 238 of 626 cities. | tongren
# Retrieving info for 239 of 626 cities. | kalianget
# Retrieving info for 240 of 626 cities. | saint andrews
# Retrieving info for 241 of 626 cities. | ranfurly
# Retrieving info for 242 of 626 cities. | ketchikan
# No matching city found.  Skipped. | tasbuget
# Retrieving info for 244 of 626 cities. | yuxia
# Retrieving info for 245 of 626 cities. | prestea
# Retrieving info for 246 of 626 cities. | mae hong son
# Retrieving info for 247 of 626 cities. | leningradskiy
# Retrieving info for 248 of 626 cities. | olinda
# Retrieving info for 249 of 626 cities. | zhob
# Retrieving info for 250 of 626 cities. | constitucion
# Retrieving info for 251 of 626 cities. | pilar
# Retrieving info for 252 of 626 cities. | ballina
# Retrieving info for 253 of 626 cities. | presidencia roque saenz pena
# No matching city found.  Skipped. | toliary
# No matching city found.  Skipped. | lata
# Retrieving info for 256 of 626 cities. | victor harbor
# Retrieving info for 257 of 626 cities. | soyo
# Retrieving info for 258 of 626 cities. | chokurdakh
# Retrieving info for 259 of 626 cities. | pacific grove
# No matching city found.  Skipped. | barbar
# Retrieving info for 261 of 626 cities. | severo-kurilsk
# Retrieving info for 262 of 626 cities. | nerchinskiy zavod
# Retrieving info for 263 of 626 cities. | pandharpur
# Retrieving info for 264 of 626 cities. | katherine
# Retrieving info for 265 of 626 cities. | broken hill
# Retrieving info for 266 of 626 cities. | ilulissat
# No matching city found.  Skipped. | belushya guba
# Retrieving info for 268 of 626 cities. | leninsk
# Retrieving info for 269 of 626 cities. | richards bay
# Retrieving info for 270 of 626 cities. | jizan
# Retrieving info for 271 of 626 cities. | luanda
# Retrieving info for 272 of 626 cities. | saint-louis
# Retrieving info for 273 of 626 cities. | cayenne
# Retrieving info for 274 of 626 cities. | souillac
# Retrieving info for 275 of 626 cities. | lyngdal
# Retrieving info for 276 of 626 cities. | tasiilaq
# Retrieving info for 277 of 626 cities. | awjilah
# No matching city found.  Skipped. | airai
# Retrieving info for 279 of 626 cities. | san cristobal
# Retrieving info for 280 of 626 cities. | menongue
# Retrieving info for 281 of 626 cities. | mahebourg
# Retrieving info for 282 of 626 cities. | nikel
# Retrieving info for 283 of 626 cities. | puerto escondido
# No matching city found.  Skipped. | grand river south east
# Retrieving info for 285 of 626 cities. | vestmannaeyjar
# Retrieving info for 286 of 626 cities. | great yarmouth
# Retrieving info for 287 of 626 cities. | jaciara
# No matching city found.  Skipped. | khormuj
# Retrieving info for 289 of 626 cities. | san vicente
# Retrieving info for 290 of 626 cities. | denpasar
# Retrieving info for 291 of 626 cities. | kirakira
# Retrieving info for 292 of 626 cities. | carnarvon
# No matching city found.  Skipped. | mizpe ramon
# No matching city found.  Skipped. | kerteh
# Retrieving info for 295 of 626 cities. | lichinga
# Retrieving info for 296 of 626 cities. | megion
# Retrieving info for 297 of 626 cities. | ancud
# No matching city found.  Skipped. | agsu
# Retrieving info for 299 of 626 cities. | tevriz
# Retrieving info for 300 of 626 cities. | gillette
# Retrieving info for 301 of 626 cities. | tukrah
# Retrieving info for 302 of 626 cities. | agirish
# Retrieving info for 303 of 626 cities. | prado
# Retrieving info for 304 of 626 cities. | biu
# Retrieving info for 305 of 626 cities. | tecoanapa
# Retrieving info for 306 of 626 cities. | palu
# Retrieving info for 307 of 626 cities. | mkushi
# Retrieving info for 308 of 626 cities. | pafos
# Retrieving info for 309 of 626 cities. | quatre cocos
# Retrieving info for 310 of 626 cities. | viet tri
# Retrieving info for 311 of 626 cities. | mount gambier
# Retrieving info for 312 of 626 cities. | kamenka
# Retrieving info for 313 of 626 cities. | sayyan
# Retrieving info for 314 of 626 cities. | nebbi
# Retrieving info for 315 of 626 cities. | yeppoon
# No matching city found.  Skipped. | vila
# Retrieving info for 317 of 626 cities. | nemuro
# Retrieving info for 318 of 626 cities. | zavoronezhskoye
# Retrieving info for 319 of 626 cities. | husavik
# Retrieving info for 320 of 626 cities. | altea
# Retrieving info for 321 of 626 cities. | bolgar
# Retrieving info for 322 of 626 cities. | laramie
# Retrieving info for 323 of 626 cities. | comodoro rivadavia
# No matching city found.  Skipped. | artyk
# No matching city found.  Skipped. | gilazi
# Retrieving info for 326 of 626 cities. | srednekolymsk
# Retrieving info for 327 of 626 cities. | longyearbyen
# Retrieving info for 328 of 626 cities. | fortuna
# Retrieving info for 329 of 626 cities. | jaguarao
# Retrieving info for 330 of 626 cities. | pobe
# Retrieving info for 331 of 626 cities. | port moresby
# Retrieving info for 332 of 626 cities. | cap malheureux
# No matching city found.  Skipped. | tsihombe
# Retrieving info for 334 of 626 cities. | karema
# Retrieving info for 335 of 626 cities. | tiznit
# No matching city found.  Skipped. | louisbourg
# Retrieving info for 337 of 626 cities. | bandarbeyla
# Retrieving info for 338 of 626 cities. | grindavik
# Retrieving info for 339 of 626 cities. | coos bay
# Retrieving info for 340 of 626 cities. | ovre ardal
# Retrieving info for 341 of 626 cities. | peterhead
# Retrieving info for 342 of 626 cities. | charters towers
# Retrieving info for 343 of 626 cities. | los algarrobos
# Retrieving info for 344 of 626 cities. | turukhansk
# Retrieving info for 345 of 626 cities. | sinnamary
# Retrieving info for 346 of 626 cities. | san quintin
# Retrieving info for 347 of 626 cities. | saiha
# No matching city found.  Skipped. | burica
# Retrieving info for 349 of 626 cities. | buraydah
# Retrieving info for 350 of 626 cities. | porto novo
# Retrieving info for 351 of 626 cities. | samarinda
# Retrieving info for 352 of 626 cities. | berlevag
# Retrieving info for 353 of 626 cities. | tabuk
# Retrieving info for 354 of 626 cities. | mecca
# Retrieving info for 355 of 626 cities. | manuk mangkaw
# Retrieving info for 356 of 626 cities. | katsuura
# Retrieving info for 357 of 626 cities. | yingcheng
# Retrieving info for 358 of 626 cities. | samarai
# Retrieving info for 359 of 626 cities. | lingao
# Retrieving info for 360 of 626 cities. | puerto del rosario
# Retrieving info for 361 of 626 cities. | lorengau
# Retrieving info for 362 of 626 cities. | beloha
# Retrieving info for 363 of 626 cities. | umarkot
# Retrieving info for 364 of 626 cities. | roebourne
# Retrieving info for 365 of 626 cities. | tezu
# Retrieving info for 366 of 626 cities. | tokur
# No matching city found.  Skipped. | ijaki
# Retrieving info for 368 of 626 cities. | dubbo
# Retrieving info for 369 of 626 cities. | havre
# Retrieving info for 370 of 626 cities. | hun
# Retrieving info for 371 of 626 cities. | margate
# No matching city found.  Skipped. | bac can
# No matching city found.  Skipped. | tokmak
# No matching city found.  Skipped. | yunjinghong
# Retrieving info for 375 of 626 cities. | anadyr
# Retrieving info for 376 of 626 cities. | maldonado
# Retrieving info for 377 of 626 cities. | marsh harbour
# Retrieving info for 378 of 626 cities. | henties bay
# Retrieving info for 379 of 626 cities. | brokopondo
# Retrieving info for 380 of 626 cities. | malayal
# Retrieving info for 381 of 626 cities. | deputatskiy
# Retrieving info for 382 of 626 cities. | kavaratti
# Retrieving info for 383 of 626 cities. | muros
# Retrieving info for 384 of 626 cities. | catamarca
# Retrieving info for 385 of 626 cities. | manokwari
# Retrieving info for 386 of 626 cities. | san patricio
# Retrieving info for 387 of 626 cities. | kruisfontein
# Retrieving info for 388 of 626 cities. | mulchen
# Retrieving info for 389 of 626 cities. | broome
# No matching city found.  Skipped. | eskasem
# Retrieving info for 391 of 626 cities. | manglaur
# Retrieving info for 392 of 626 cities. | joshimath
# Retrieving info for 393 of 626 cities. | sabzevar
# Retrieving info for 394 of 626 cities. | macapa
# Retrieving info for 395 of 626 cities. | bourail
# Retrieving info for 396 of 626 cities. | kavieng
# Retrieving info for 397 of 626 cities. | lac du bonnet
# Retrieving info for 398 of 626 cities. | novopokrovka
# Retrieving info for 399 of 626 cities. | tiksi
# Retrieving info for 400 of 626 cities. | razole
# Retrieving info for 401 of 626 cities. | junction city
# Retrieving info for 402 of 626 cities. | bangassou
# Retrieving info for 403 of 626 cities. | itaqui
# No matching city found.  Skipped. | halalo
# No matching city found.  Skipped. | samusu
# Retrieving info for 406 of 626 cities. | farah
# Retrieving info for 407 of 626 cities. | haines junction
# Retrieving info for 408 of 626 cities. | nanyamba
# No matching city found.  Skipped. | papasquiaro
# Retrieving info for 410 of 626 cities. | gorontalo
# Retrieving info for 411 of 626 cities. | coahuayana
# Retrieving info for 412 of 626 cities. | mareeba
# Retrieving info for 413 of 626 cities. | kazachinskoye
# Retrieving info for 414 of 626 cities. | tarakan
# No matching city found.  Skipped. | fevralsk
# Retrieving info for 416 of 626 cities. | road town
# Retrieving info for 417 of 626 cities. | bomi
# Retrieving info for 418 of 626 cities. | mozarlandia
# Retrieving info for 419 of 626 cities. | vanimo
# Retrieving info for 420 of 626 cities. | harper
# Retrieving info for 421 of 626 cities. | santa cruz
# Retrieving info for 422 of 626 cities. | hangu
# Retrieving info for 423 of 626 cities. | lagoa
# Retrieving info for 424 of 626 cities. | vostok
# Retrieving info for 425 of 626 cities. | sheffield
# Retrieving info for 426 of 626 cities. | olafsvik
# Retrieving info for 427 of 626 cities. | waitati
# Retrieving info for 428 of 626 cities. | barkhan
# Retrieving info for 429 of 626 cities. | jiaocheng
# Retrieving info for 430 of 626 cities. | tiarei
# Retrieving info for 431 of 626 cities. | kudahuvadhoo
# No matching city found.  Skipped. | utiroa
# Retrieving info for 433 of 626 cities. | ulladulla
# Retrieving info for 434 of 626 cities. | gibsons
# Retrieving info for 435 of 626 cities. | athabasca
# Retrieving info for 436 of 626 cities. | kangaatsiaq
# Retrieving info for 437 of 626 cities. | flinders
# No matching city found.  Skipped. | vaitupu
# Retrieving info for 439 of 626 cities. | bambous virieux
# Retrieving info for 440 of 626 cities. | cascais
# Retrieving info for 441 of 626 cities. | zhigansk
# Retrieving info for 442 of 626 cities. | half moon bay
# Retrieving info for 443 of 626 cities. | kautokeino
# Retrieving info for 444 of 626 cities. | plettenberg bay
# No matching city found.  Skipped. | himora
# Retrieving info for 446 of 626 cities. | oktyabrskoye
# Retrieving info for 447 of 626 cities. | dobrany
# Retrieving info for 448 of 626 cities. | tura
# Retrieving info for 449 of 626 cities. | nouadhibou
# Retrieving info for 450 of 626 cities. | la ronge
# Retrieving info for 451 of 626 cities. | ejea de los caballeros
# Retrieving info for 452 of 626 cities. | angoche
# Retrieving info for 453 of 626 cities. | bom jesus da lapa
# Retrieving info for 454 of 626 cities. | nanortalik
# Retrieving info for 455 of 626 cities. | barcelos
# No matching city found.  Skipped. | buin
# No matching city found.  Skipped. | rungata
# Retrieving info for 458 of 626 cities. | fairbanks
# No matching city found.  Skipped. | saleaula
# Retrieving info for 460 of 626 cities. | antofagasta
# Retrieving info for 461 of 626 cities. | atocha
# Retrieving info for 462 of 626 cities. | cockburn town
# Retrieving info for 463 of 626 cities. | beringovskiy
# Retrieving info for 464 of 626 cities. | vuktyl
# Retrieving info for 465 of 626 cities. | hays
# Retrieving info for 466 of 626 cities. | babu
# Retrieving info for 467 of 626 cities. | totma
# Retrieving info for 468 of 626 cities. | mantua
# Retrieving info for 469 of 626 cities. | kununurra
# Retrieving info for 470 of 626 cities. | bonavista
# Retrieving info for 471 of 626 cities. | saint-joseph
# Retrieving info for 472 of 626 cities. | acapulco
# Retrieving info for 473 of 626 cities. | gallatin
# No matching city found.  Skipped. | guinsiliban
# Retrieving info for 475 of 626 cities. | northam
# No matching city found.  Skipped. | gat
# Retrieving info for 477 of 626 cities. | palana
# Retrieving info for 478 of 626 cities. | sao raimundo nonato
# Retrieving info for 479 of 626 cities. | kifri
# Retrieving info for 480 of 626 cities. | qandala
# Retrieving info for 481 of 626 cities. | los negros
# No matching city found.  Skipped. | galiwinku
# No matching city found.  Skipped. | taburao
# Retrieving info for 484 of 626 cities. | grand gaube
# Retrieving info for 485 of 626 cities. | mugumu
# Retrieving info for 486 of 626 cities. | seminole
# No matching city found.  Skipped. | ituni
# Retrieving info for 488 of 626 cities. | pokosnoye
# Retrieving info for 489 of 626 cities. | bredy
# Retrieving info for 490 of 626 cities. | laksar
# Retrieving info for 491 of 626 cities. | tessalit
# Retrieving info for 492 of 626 cities. | zvishavane
# Retrieving info for 493 of 626 cities. | khingansk
# Retrieving info for 494 of 626 cities. | alofi
# Retrieving info for 495 of 626 cities. | ghogha
# Retrieving info for 496 of 626 cities. | linjiang
# Retrieving info for 497 of 626 cities. | wasilla
# Retrieving info for 498 of 626 cities. | tucumcari
# No matching city found.  Skipped. | warqla
# Retrieving info for 500 of 626 cities. | kamsack
# No matching city found.  Skipped. | tumannyy
# Retrieving info for 502 of 626 cities. | bulgan
# Retrieving info for 503 of 626 cities. | bembereke
# Retrieving info for 504 of 626 cities. | bayshore gardens
# Retrieving info for 505 of 626 cities. | tingo maria
# Retrieving info for 506 of 626 cities. | sayat
# No matching city found.  Skipped. | westpunt
# No matching city found.  Skipped. | aakirkeby
# Retrieving info for 509 of 626 cities. | zottegem
# Retrieving info for 510 of 626 cities. | college
# Retrieving info for 511 of 626 cities. | kitimat
# Retrieving info for 512 of 626 cities. | hovd
# Retrieving info for 513 of 626 cities. | sitka
# Retrieving info for 514 of 626 cities. | wajima
# Retrieving info for 515 of 626 cities. | miandrivazo
# Retrieving info for 516 of 626 cities. | roma
# No matching city found.  Skipped. | cumaribo
# Retrieving info for 518 of 626 cities. | brae
# Retrieving info for 519 of 626 cities. | tobol
# Retrieving info for 520 of 626 cities. | tournon-sur-rhone
# Retrieving info for 521 of 626 cities. | san policarpo
# Retrieving info for 522 of 626 cities. | hashtrud
# Retrieving info for 523 of 626 cities. | chernenko
# Retrieving info for 524 of 626 cities. | kasongo-lunda
# Retrieving info for 525 of 626 cities. | vila velha
# No matching city found.  Skipped. | mrirt
# Retrieving info for 527 of 626 cities. | luancheng
# Retrieving info for 528 of 626 cities. | palafrugell
# Retrieving info for 529 of 626 cities. | kenai
# Retrieving info for 530 of 626 cities. | moron
# Retrieving info for 531 of 626 cities. | salvador
# Retrieving info for 532 of 626 cities. | vysokogornyy
# Retrieving info for 533 of 626 cities. | burbank
# Retrieving info for 534 of 626 cities. | san francisco
# Retrieving info for 535 of 626 cities. | hofn
# Retrieving info for 536 of 626 cities. | sao felix do xingu
# Retrieving info for 537 of 626 cities. | kailua
# Retrieving info for 538 of 626 cities. | apple valley
# Retrieving info for 539 of 626 cities. | minot
# Retrieving info for 540 of 626 cities. | chumikan
# Retrieving info for 541 of 626 cities. | shilka
# Retrieving info for 542 of 626 cities. | vieux-habitants
# Retrieving info for 543 of 626 cities. | howard springs
# Retrieving info for 544 of 626 cities. | mudgee
# Retrieving info for 545 of 626 cities. | shimoda
# Retrieving info for 546 of 626 cities. | promyshlennyy
# Retrieving info for 547 of 626 cities. | rio grande
# Retrieving info for 548 of 626 cities. | humberto de campos
# Retrieving info for 549 of 626 cities. | jimo
# Retrieving info for 550 of 626 cities. | dubrovnik
# Retrieving info for 551 of 626 cities. | manacapuru
# Retrieving info for 552 of 626 cities. | jilib
# Retrieving info for 553 of 626 cities. | vysha
# Retrieving info for 554 of 626 cities. | otavi
# Retrieving info for 555 of 626 cities. | muzhi
# Retrieving info for 556 of 626 cities. | hue
# Retrieving info for 557 of 626 cities. | anderson
# Retrieving info for 558 of 626 cities. | gidole
# Retrieving info for 559 of 626 cities. | lancut
# Retrieving info for 560 of 626 cities. | borovoy
# Retrieving info for 561 of 626 cities. | bethel
# No matching city found.  Skipped. | phan rang
# Retrieving info for 563 of 626 cities. | trincomalee
# Retrieving info for 564 of 626 cities. | pimentel
# Retrieving info for 565 of 626 cities. | mildura
# Retrieving info for 566 of 626 cities. | maragogi
# Retrieving info for 567 of 626 cities. | fare
# Retrieving info for 568 of 626 cities. | carmen
# No matching city found.  Skipped. | burkhala
# Retrieving info for 570 of 626 cities. | san juan bautista
# Retrieving info for 571 of 626 cities. | maniitsoq
# Retrieving info for 572 of 626 cities. | torrington
# Retrieving info for 573 of 626 cities. | erzincan
# Retrieving info for 574 of 626 cities. | popondetta
# Retrieving info for 575 of 626 cities. | dakar
# Retrieving info for 576 of 626 cities. | vechta
# Retrieving info for 577 of 626 cities. | portland
# Retrieving info for 578 of 626 cities. | ust-kishert
# Retrieving info for 579 of 626 cities. | valley
# Retrieving info for 580 of 626 cities. | lubango
# No matching city found.  Skipped. | haibowan
# Retrieving info for 582 of 626 cities. | mabai
# Retrieving info for 583 of 626 cities. | fethiye
# Retrieving info for 584 of 626 cities. | mahon
# Retrieving info for 585 of 626 cities. | ugoofaaru
# Retrieving info for 586 of 626 cities. | ambilobe
# Retrieving info for 587 of 626 cities. | gobabis
# Retrieving info for 588 of 626 cities. | coruripe
# Retrieving info for 589 of 626 cities. | majene
# Retrieving info for 590 of 626 cities. | kyzyl
# Retrieving info for 591 of 626 cities. | zaysan
# Retrieving info for 592 of 626 cities. | wanaka
# Retrieving info for 593 of 626 cities. | taoudenni
# Retrieving info for 594 of 626 cities. | honghu
# Retrieving info for 595 of 626 cities. | sukhobezvodnoye
# Retrieving info for 596 of 626 cities. | gamba
# Retrieving info for 597 of 626 cities. | batagay-alyta
# Retrieving info for 598 of 626 cities. | esso
# Retrieving info for 599 of 626 cities. | salingogon
# Retrieving info for 600 of 626 cities. | amga
# No matching city found.  Skipped. | codrington
# Retrieving info for 602 of 626 cities. | fort nelson
# Retrieving info for 603 of 626 cities. | shelburne
# Retrieving info for 604 of 626 cities. | nizamabad
# Retrieving info for 605 of 626 cities. | mbanza-ngungu
# Retrieving info for 606 of 626 cities. | machala
# No matching city found.  Skipped. | chengmai
# Retrieving info for 608 of 626 cities. | bundaberg
# Retrieving info for 609 of 626 cities. | morro bay
# Retrieving info for 610 of 626 cities. | bukama
# Retrieving info for 611 of 626 cities. | central point
# Retrieving info for 612 of 626 cities. | askiz
# Retrieving info for 613 of 626 cities. | motygino
# Retrieving info for 614 of 626 cities. | kieta
# Retrieving info for 615 of 626 cities. | belyy yar
# Retrieving info for 616 of 626 cities. | byron bay
# Retrieving info for 617 of 626 cities. | young
# Retrieving info for 618 of 626 cities. | ogre
# Retrieving info for 619 of 626 cities. | mushie
# Retrieving info for 620 of 626 cities. | sorland
# Retrieving info for 621 of 626 cities. | mohgaon
# Retrieving info for 622 of 626 cities. | port-de-bouc
# Retrieving info for 623 of 626 cities. | ransang
# Retrieving info for 624 of 626 cities. | pak phanang
# Retrieving info for 625 of 626 cities. | inhambane
# Retrieving info for 626 of 626 cities. | gamboula

# %%
print(len(city_list), len(city_lat), len(city_lng), len(weather), len(humidity), len(cloudiness), len(wind_speed))
# Out:
# 550 550 550 550 550 550 550

# %%
weather_df = pd.DataFrame({"City": city_list, 
                           "Country": country_list,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Temperature (F)": weather,
                          "Humidity": humidity,
                          "Cloudiness": cloudiness,
                          "Wind Speed (mph)": wind_speed})

weather_clean_df = weather_df.loc[weather_df["Humidity"] < 100]

weather_df.to_csv(output_data)



weather_df.head()
# Out:
#           City Country      Lat       Lng  Temperature (F)  Humidity  \
# 0         chuy      uy -33.6971  -53.4616            73.26        56
# 1  new norfolk      au -42.7826  147.0587            44.80        55
# 2    hithadhoo      mv  -0.6000   73.0833            80.83        64
# 3       dillon      us  34.4166  -79.3712            53.87        35
# 4     saldanha      za -33.0117   17.9442            69.80        68
#
#    Cloudiness  Wind Speed (mph)
# 0           0             12.46
# 1          62              1.99
# 2           0              3.09
# 3           1             19.57
# 4           0              9.22

# %%
plt.scatter(weather_clean_df["Lat"], weather_clean_df["Temperature (F)"])
plt.title("Temperature vs. Latitude 1/18/21")
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")
plt.savefig("../Images/Temperature_Latitude_1-18-21.png")

# %%
plt.scatter(weather_clean_df["Lat"], weather_clean_df["Humidity"])
plt.title("Humidity (%) vs. Latitude 1/18/21")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

plt.savefig("../Images/Humidity_Latitude_1-18-21.png")

# %%
plt.scatter(weather_clean_df["Lat"], weather_clean_df["Cloudiness"])
plt.title("Cloudiness vs. Latitude 1/18/21")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")

plt.savefig("../Images/Cloudiness_Latitude_1-18-21.png")

# %%
plt.scatter(weather_clean_df["Lat"], weather_clean_df["Wind Speed (mph)"])
plt.title("Wind Speed (mph) vs. Latitude 1/18/21")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

plt.savefig("../Images/WindSpeed_Latitude_1-18-21.png")

# %%
northern_df = weather_clean_df.loc[weather_clean_df["Lat"] >= 0]

southern_df = weather_clean_df.loc[weather_clean_df["Lat"] < 0]

def regress(x,y):
    global slope, intercept, rvalue, pvalue, stderr, regress_values, line_eq
    (slope, intercept, rvalue, pvalue, stderr) = st.linregress(x,y)
    regress_values = x * slope + intercept
    plt.plot(x, regress_values, "-", color="blue")
    line_eq = "y= " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))

# %%
x = northern_df["Lat"]
y = northern_df["Temperature (F)"]


plt.scatter(x, y, c="red")
plt.title("Northern Hemisphere Temperature vs. Latitude 1/18/21")
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")


regress(x,y)
plt.annotate(line_eq, (0, 10), fontsize=15, color="blue")

plt.savefig("../Images/Nothern_Hemisphere_Temperature_Latitude_1-18-21.png")
print(f"The r-value is: {rvalue}")
# Out:
# The r-value is: -0.8409940428530249

# %%
x = southern_df["Lat"]
y = southern_df["Temperature (F)"]


plt.scatter(x, y, c="green")
plt.title("Southern Hemisphere Temperature (F) vs. Latitude 1/18/21")
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")

regress(x, y)
plt.annotate(line_eq, (-50, 50), fontsize=15, color="blue")
plt.savefig("../Images/Southern_Hemisphere_Temperature_Latitude_1-18-21.png")
print(f"The r-value is: {rvalue}")
# Out:
# The r-value is: 0.5348884788257173

# %%
x = northern_df["Lat"]
y = northern_df["Humidity"]


plt.scatter(x, y, c="red")
plt.title("Northern Hemisphere Humidity (%)a vs. Latitude 1/18/21")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")


regress(x,y)
plt.annotate(line_eq, (20, 10), fontsize=15, color="blue")

plt.savefig("../Images/Nothern_Hemisphere_Humidity_Latitude_1-18-21.png")
print(f"The r-value is: {rvalue}")
# Out:
# The r-value is: 0.4176983795912178

# %%
x = southern_df["Temperature (F)"]
y = southern_df["Lat"]

plt.scatter(x, y, c="green")
plt.title("Southern Hemisphere Humidity (%) vs. Latitude 1/18/21")
plt.xlabel("Humidity (%)")
plt.ylabel("Latitude")

regress(x, y)
plt.annotate(line_eq, (50, -50), fontsize=15, color="blue")
plt.savefig("../Images/Southern_Hemisphere_Humidity_Latitude_1-18-21.png")
print(f"The r-value is: {rvalue}")
# Out:
# The r-value is: 0.5348884788257173

# %%
x = northern_df["Lat"]
y = northern_df["Cloudiness"]


plt.scatter(x, y, c="red")
plt.title("Northern Hemisphere Cloudiness (%) vs. Latitude 1/18/21")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")


regress(x,y)
plt.annotate(line_eq, (10, 10), fontsize=15, color="blue")
plt.savefig("../Images/Nothern_Hemisphere_Cloudiness_Latitude_1-18-21.png")
print(f"The r-value is: {rvalue}")
# Out:
# The r-value is: 0.1474386611130609

# %%
x = southern_df["Lat"]
y = southern_df["Cloudiness"]


plt.scatter(x, y, c="green")
plt.title("Southern Hemisphere Cloudiness (%) vs. Latitude 1/18/21")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")


regress(x, y)
plt.annotate(line_eq, (-50, 20), fontsize=15, color="blue")
plt.savefig("../Images/Southern_Hemisphere_Cloudiness_Latitude_1-18-21.png")
print(f"The r-value is: {rvalue}")
# Out:
# The r-value is: 0.23336307046932417

# %%
x = northern_df["Lat"]
y = northern_df["Wind Speed (mph)"]


plt.scatter(x, y, c="red")
plt.title("Northern Hemisphere Wind Speed (mph) vs. Latitude 1/18/21")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")


regress(x,y)
plt.annotate(line_eq, (0, 30), fontsize=15, color="blue")
plt.savefig("../Images/Nothern_Hemisphere_WindSpeed_Latitude_1-18-21.png")
print(f"The r-value is: {rvalue}")
# Out:
# The r-value is: 0.02746808026090916

# %%
x = southern_df["Lat"]
y = southern_df["Wind Speed (mph)"]


plt.scatter(x, y, c="green")
plt.title("Southern Hemisphere Wind Speed (mph) vs. Latitude 1/18/21")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")


regress(x, y)
plt.annotate(line_eq, (-55, 17), fontsize=15, color="blue")
plt.savefig("../Images/Southern_Hemisphere_WindSpeed_Latitude_1-18-21.png")
print(f"The r-value is: {rvalue}")
# Out:
# The r-value is: -0.1971272670827878
